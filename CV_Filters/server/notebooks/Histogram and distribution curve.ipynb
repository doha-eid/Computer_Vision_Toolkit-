# %%
import cv2 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.stats import norm
import numpy as np

# %%
# r,g,b=RGBhistogram(img)
# data=[r,g,b]
# mu, std = norm.fit(data)

# %%
imgpath = "D:/SBME/3rd Year/Computer Vision/Task1_cv/server/static/assests/image1.jpg"
img = cv2.imread(imgpath)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
red_hist = cv2.calcHist([img], [0], None, [256], [0, 255])
green_hist = cv2.calcHist([img], [1], None, [256], [0, 255])
blue_hist = cv2.calcHist([img], [2], None, [256], [0, 255])
data=[red_hist,green_hist,blue_hist]
mu, std = norm.fit(data)

# %%
plt.subplot(3, 1, 1)

plt.subplot(3, 1, 1)
plt.plot(red_hist, color='r')
plt.xlim([0, 255])
plt.title('red histogram')

plt.subplot(3, 1, 2)
plt.plot(green_hist, color='g')
plt.xlim([0, 255])
plt.title('green histogram')

plt.subplot(3, 1, 3)
plt.plot(blue_hist, color='b')
plt.xlim([0, 255])
plt.title('blue histogram')

plt.tight_layout()
plt.show()

# %%
plt.plot(red_hist,color="r")
plt.plot(green_hist,color="g")
plt.plot(blue_hist,color="b")

# %%
plt.hist(red_hist,color="r")
plt.hist(green_hist,color="g")
plt.hist(blue_hist,color="b")
# Out:
# (array([255.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([     0.        ,  12459.90039062,  24919.80078125,  37379.69921875,
#          49839.6015625 ,  62299.5       ,  74759.3984375 ,  87219.296875  ,
#          99679.203125  , 112139.1015625 , 124599.        ]),
#  <BarContainer object of 10 artists>)
